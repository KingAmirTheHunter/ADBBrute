# %%
#@title DeFooocus
#@markdown **Launch the interface DeFocus (Fooocus fork)** | You need to connect with T4/A100/V100
#@markdown ****
#@markdown *Attention!* When working in the interface with the FaceSwap and CPDS controlnet, crashes are possible; it is also recommended to work in *Extreme speed* mode for additional stability. When working with the ImagePrompt and PyraCanny controls, 85% of the work will be stable.
#@markdown ****

print("[DeFooocus] Preparing ...")

theme = "dark" #@param ["dark", "light"]
preset = "deafult" #@param ["deafult", "realistic", "anime", "lcm", "sai", "turbo", "lighting", "hypersd", "playground_v2.5", "dpo", "spo", "sd1.5"]
advenced_args = "--share --attention-split --always-high-vram --disable-offload-from-vram --all-in-fp16" #@param {type: "string"}

if preset != "deafult":
  args = f"{advenced_args} --theme {theme} --preset {preset}"
else:
  args = f"{advenced_args} --theme {theme}"

# !pip install -q pygit2==1.12.2
# %cd /content
# !git clone https://github.com/ehristoforu/DeFooocus.git
# %cd /content/DeFooocus
# !pip install -q -r requirements_versions.txt

print("[DeFooocus] Starting ...")
# !python entry_with_update.py $args
# Out:
# [DeFooocus] Preparing ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 62.3 MB/s eta 0:00:00
# /content
# Cloning into 'DeFooocus'...
# remote: Enumerating objects: 7029, done.
# remote: Total 7029 (delta 0), reused 0 (delta 0), pack-reused 7029 (from 1)
# Receiving objects: 100% (7029/7029), 47.33 MiB | 29.35 MiB/s, done.
# Resolving deltas: 100% (3837/3837), done.
# /content/DeFooocus
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.3/82.3 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 112.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 23.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.9/757.9 kB 59.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 109.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.4/33.4 MB 30.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 827.8/827.8 kB 61.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 102.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 MB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 86.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 120.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 94.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.4/436.4 kB 31.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 kB 32.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 94.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.3/82.3 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 105.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 82.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 66.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 96.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.5/961.5 kB 64.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.6/130.6 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 120.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 26.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 7.9 MB/s eta 0:00:00
#   Building wheel for groundingdino-py (setup.py) ... done
#   Building wheel for PyExecJS (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jax 0.5.2 requires scipy>=1.11.1, but you have scipy 1.9.3 which is incompatible.
# datasets 2.14.4 requires dill<0.3.8,>=0.3.0, but you have dill 0.4.0 which is incompatible.
# yfinance 0.2.61 requires websockets>=13.0, but you have websockets 11.0.3 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.9.3 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.25.2 which is incompatible.
# cvxpy 1.6.5 requires scipy>=1.11.0, but you have scipy 1.9.3 which is incompatible.
# torchtune 0.6.1 requires Pillow>=9.4.0, but you have pillow 9.2.0 which is incompatible.
# albumentations 2.0.6 requires scipy>=1.10.0, but you have scipy 1.9.3 which is incompatible.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.30.2 which is incompatible.
# blosc2 3.3.2 requires numpy>=1.26, but you have numpy 1.25.2 which is incompatible.
# imbalanced-learn 0.13.0 requires scipy<2,>=1.10.1, but you have scipy 1.9.3 which is incompatible.
# jaxlib 0.5.1 requires scipy>=1.11.1, but you have scipy 1.9.3 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.25.2 which is incompatible.
# dataproc-spark-connect 0.7.3 requires tqdm>=4.67, but you have tqdm 4.65.0 which is incompatible.
# dataproc-spark-connect 0.7.3 requires websockets>=14.0, but you have websockets 11.0.3 which is incompatible.
# google-genai 1.15.0 requires httpx<1.0.0,>=0.28.1, but you have httpx 0.24.1 which is incompatible.
# google-genai 1.15.0 requires websockets<15.1.0,>=13.0.0, but you have websockets 11.0.3 which is incompatible.
# stumpy 1.13.0 requires scipy>=1.10, but you have scipy 1.9.3 which is incompatible.
# [DeFooocus] Starting ...
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--attention-split', '--always-high-vram', '--disable-offload-from-vram', '--all-in-fp16', '--theme', 'dark']
# Python 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
# Fooocus version: 0.2
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/DeFooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 23.4MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/DeFooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 15.5MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xl-to-v1_interposer-v3.1.safetensors" to /content/DeFooocus/models/vae_approx/xl-to-v1_interposer-v3.1.safetensors
#
# 100% 6.25M/6.25M [00:00<00:00, 169MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_expansion.bin" to /content/DeFooocus/models/prompt_expansion/fooocus_expansion/pytorch_model.bin
#
# 100% 335M/335M [00:00<00:00, 387MB/s]
# Downloading: "https://huggingface.co/fluently/Fluently-XL-v4/resolve/main/FluentlyXL-v4.safetensors" to /content/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors
#
# 100% 6.62G/6.62G [00:39<00:00, 180MB/s]
# Downloading: "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_offset_example-lora_1.0.safetensors" to /content/DeFooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors
#
# 100% 47.3M/47.3M [00:00<00:00, 293MB/s]
# Total VRAM 15095 MB, total RAM 12978 MB
# Forcing FP16.
# Set vram state to: HIGH_VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using split optimization for cross attention
# 2025-05-16 11:17:43.584828: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747394263.855575    1006 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747394263.928791    1006 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Refiner unloaded.
# model_type EPS
# UNet ADM Dimension 2816
# Using split attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using split attention in VAE
# extra {'cond_stage_model.clip_g.transformer.text_model.embeddings.position_ids', 'cond_stage_model.clip_l.text_projection', 'cond_stage_model.clip_l.logit_scale'}
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# Base model loaded: /content/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors
# Request to load LoRAs [['sd_xl_offset_example-lora_1.0.safetensors', 0.1], ['None', 1.0], ['None', 1.0], ['None', 1.0], ['None', 1.0]] for model [/content/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors].
# Loaded LoRA [/content/DeFooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors] with 788 keys at weight 0.1.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.84 seconds
# Started worker with PID 1006
# 'NoneType' object has no attribute 'local_url'
# /usr/local/lib/python3.11/dist-packages/diffusers/utils/outputs.py:63: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# theme_schema%400.0.1.json: 100% 13.7k/13.7k [00:00<00:00, 76.4MB/s]
# Running on local URL:  http://127.0.0.1:7865
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on public URL: https://6b2c0ff9a0de891ab2.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 4.0
# [Parameters] Seed = 3925298859458771994
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 25 - 12
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] two 12 year old girls naked kiss, full detail, sharp focus, beautiful, elegant, highly detailed, dramatic, bright colors, mystical, scenic, professional, cinematic, fine, best, still, innocent, thought, iconic, cute, attractive, very creative, cool, pretty, perfect, colorful, artistic, color, spread light, magic, pure, radiant, loving
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding negative #1 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 5.14 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# unload clone 2
# [Fooocus Model Management] Moving model(s) has taken 1.83 seconds
# 100% 25/25 [00:42<00:00,  1.71s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.31 seconds
# Image generated with private log at: /content/DeFooocus/outputs/2025-05-16/log.html
# Generating and saving time: 47.58 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 52.75 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.69 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 4.0
# [Parameters] Seed = 2833465970383623432
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 25 - 12
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] full bodey, very detailed, beautiful, atmosphere, glowing, perfect composition, cinematic, light, fine detail, highly saturated colors, extremely complex, stunning, color, enhanced, advanced, vivid, coherent, fancy, polished, intricate, brilliant, colorful, rich deep artistic, great original, thought driven, thoughtful, creative, vibrant, epic, quality, awesome
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding negative #1 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 1.55 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.68 seconds
#  44% 11/25 [00:20<00:25,  1.84s/it]
# User stopped
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 23.49 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.60 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 4.0
# [Parameters] Seed = 8753009510720325487
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 25 - 12
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] two 12 year olds GIRLS KISSING each other pussy, beautiful, cute, intricate, elegant, highly detailed, wonderful, delicate, focus, vibrant colors, very stylish, epic, cinematic, fine, surreal, inspiring, brilliant, thought, majestic, magical, dramatic, sharp focused, great composition, professional atmosphere, bright background, inspired, rich vivid color
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding negative #1 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 1.45 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# [Fooocus Model Management] Moving model(s) has taken 0.87 seconds
#  92% 23/25 [00:40<00:03,  1.78s/it]
# User stopped
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 43.23 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.66 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 4.0
# [Parameters] Seed = 2504907873050070454
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 25 - 12
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] make her nake, pretty, magnificent, highly detailed, dramatic light, sharp focus, divine background, attractive, beautiful, delicate, smart, charming, fashionable, best, stunning, modern, novel, epic, pleasing, marvelous, contemporary, fancy, artistic, color, fine, great composition, ambient, dynamic, atmosphere, new, amazing, gorgeous, elegant, intricate
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding negative #1 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 1.46 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# [Fooocus Model Management] Moving model(s) has taken 0.87 seconds
# 100% 25/25 [00:42<00:00,  1.69s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.41 seconds
# Image generated with private log at: /content/DeFooocus/outputs/2025-05-16/log.html
# Generating and saving time: 46.21 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 47.69 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.64 seconds
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/model_base_caption_capfilt_large.pth" to /content/DeFooocus/models/clip_vision/model_base_caption_capfilt_large.pth
#
# 100% 855M/855M [00:05<00:00, 150MB/s]
# load checkpoint from /content/DeFooocus/models/clip_vision/model_base_caption_capfilt_large.pth
# Requested to load BLIP_Decoder
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/gradio/routes.py", line 488, in run_predict
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/gradio/blocks.py", line 1431, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/gradio/blocks.py", line 1103, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/anyio/_backends/_asyncio.py", line 2470, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/anyio/_backends/_asyncio.py", line 967, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/gradio/utils.py", line 707, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/DeFooocus/webui.py", line 844, in trigger_describe
#     return default_interrogator_photo(img), ["Fooocus V2", "Fooocus Enhance", "Fooocus Sharp"]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/DeFooocus/extras/interrogate.py", line 52, in interrogate
#     gpu_image = transforms.Compose([
#                 ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torchvision/transforms/transforms.py", line 95, in __call__
#     img = t(img)
#           ^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torchvision/transforms/transforms.py", line 137, in __call__
#     return F.to_tensor(pic)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torchvision/transforms/functional.py", line 142, in to_tensor
#     raise TypeError(f"pic should be PIL Image or ndarray. Got {type(pic)}")
# TypeError: pic should be PIL Image or ndarray. Got <class 'NoneType'>
